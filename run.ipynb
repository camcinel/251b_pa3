# %% [markdown]
# #Change directory to main folder
# ```
# %cd /content/drive/MyDrive/251b_pa3
# ```
#
# ## To run python file
# ```
# !python3 train.py
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/251b_pa3
# Out:
# /content/drive/MyDrive/251b_pa3

# %%
# %cd /content/drive/MyDrive/Study Material/Qtr 5/251b_pa3
# Out:
# /content/drive/.shortcut-targets-by-id/1iMJmKBLoeDnkOV2hi0ZxQ9u9uKuEbcOB/251b_pa3

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1iMJmKBLoeDnkOV2hi0ZxQ9u9uKuEbcOB/251b_pa3

# %% [markdown]
# # FCN_new

# %%
# !python3 train.py
# Out:
# Traceback (most recent call last):
#   File "train.py", line 86, in <module>
#     criterion = torch.nn.CrossEntropyLoss(weight=getClassWeights(train_dataset, n_classes=n_class, device=device),
#   File "train.py", line 32, in getClassWeights
#     for input, label in dataset:
#   File "/content/drive/MyDrive/251b_pa3/voc.py", line 65, in __getitem__
#     mask = Image.open(mask_path).resize((self.width, self.height))
#   File "/usr/local/lib/python3.8/dist-packages/PIL/Image.py", line 2852, in open
#     prefix = fp.read(16)
# KeyboardInterrupt
# ^C

# %% [markdown]
# # FCN

# %%
# !python3 train.py
# Out:
# Training on cuda
# Format:	[epoch/total epochs][mini batch/total batches]	Loss	IOU	Accuracy
# start training
# Finish epoch 0	Time elapsed 5.7451 seconds
# Val:	[0/100][1/1]	Loss: 4.5153	IOU: 0.0000	Acc: 0.0000
# Finish epoch 1	Time elapsed 3.0963 seconds
# Val:	[1/100][1/1]	Loss: 4.7093	IOU: 0.0002	Acc: 0.0000
# Finish epoch 2	Time elapsed 3.9061 seconds
# Val:	[2/100][1/1]	Loss: 4.1131	IOU: 0.0232	Acc: 0.0163
# Finish epoch 3	Time elapsed 3.1556 seconds
# Val:	[3/100][1/1]	Loss: 3.9344	IOU: 0.0267	Acc: 0.0204
# Finish epoch 4	Time elapsed 3.7363 seconds
# Val:	[4/100][1/1]	Loss: 3.7723	IOU: 0.0245	Acc: 0.0235
# Finish epoch 5	Time elapsed 3.1994 seconds
# Val:	[5/100][1/1]	Loss: 3.8697	IOU: 0.0266	Acc: 0.0298
# Finish epoch 6	Time elapsed 3.6815 seconds
# Val:	[6/100][1/1]	Loss: 3.7797	IOU: 0.0275	Acc: 0.0304
# Finish epoch 7	Time elapsed 3.0931 seconds
# Val:	[7/100][1/1]	Loss: 3.3918	IOU: 0.0269	Acc: 0.0371
# Finish epoch 8	Time elapsed 3.5056 seconds
# ...

# %%
# !python3 train.py
# Out:
# Training on cuda
# Format:	[epoch/total epochs][mini batch/total batches]	Loss	IOU	Accuracy
# start training
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Figure(640x480)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Figure(640x480)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Figure(640x480)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Figure(640x480)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Figure(640x480)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Figure(640x480)
# ...
